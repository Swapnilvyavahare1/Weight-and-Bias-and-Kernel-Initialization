# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import make_moons

# %%
x,y= make_moons(n_samples=500, noise=0.05, random_state=42)

# %%
plt.scatter(x[:,0], x[:,1], c=y, s=150)
plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model= Sequential()
model.add(Dense(2, activation='sigmoid', input_dim=2))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.get_weights()
# Out:
# [array([[-0.93446726,  0.60121715],
#         [ 0.3540144 ,  0.84992325]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[-0.95438635],
#         [-0.0340513 ]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
initial_weight= model.get_weights()

# %%
initial_weight[0]= np.ones(initial_weight[0].shape)*0.5
initial_weight[1]= np.ones(initial_weight[1].shape)*0.5
initial_weight[2]= np.ones(initial_weight[2].shape)*0.5
initial_weight[3]= np.ones(initial_weight[3].shape)*0.5

# %%
model.set_weights(initial_weight)

# %%
model.get_weights()
# Out:
# [array([[0.5, 0.5],
#         [0.5, 0.5]], dtype=float32),
#  array([0.5, 0.5], dtype=float32),
#  array([[0.5],
#         [0.5]], dtype=float32),
#  array([0.5], dtype=float32)]

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history= model.fit(x,y, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 5s 19ms/step - loss: 0.8679 - accuracy: 0.4875 - val_loss: 0.7918 - val_accuracy: 0.5500
# Epoch 2/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.8583 - accuracy: 0.4875 - val_loss: 0.7842 - val_accuracy: 0.5500
# Epoch 3/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.8492 - accuracy: 0.4875 - val_loss: 0.7772 - val_accuracy: 0.5500
# Epoch 4/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.8406 - accuracy: 0.4875 - val_loss: 0.7704 - val_accuracy: 0.5500
# Epoch 5/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.8319 - accuracy: 0.4875 - val_loss: 0.7641 - val_accuracy: 0.5500
# Epoch 6/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.8237 - accuracy: 0.4875 - val_loss: 0.7581 - val_accuracy: 0.5500
# Epoch 7/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.8163 - accuracy: 0.4875 - val_loss: 0.7522 - val_accuracy: 0.5500
# Epoch 8/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.8088 - accuracy: 0.4875 - val_loss: 0.7470 - val_accuracy: 0.5500
# Epoch 9/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.8017 - accuracy: 0.4875 - val_loss: 0.7419 - val_accuracy: 0.5500
# Epoch 10/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7952 - accuracy: 0.4875 - val_loss: 0.7370 - val_accuracy: 0.5500
# Epoch 11/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7888 - accuracy: 0.4875 - val_loss: 0.7322 - val_accuracy: 0.5500
# Epoch 12/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7826 - accuracy: 0.4875 - val_loss: 0.7279 - val_accuracy: 0.5500
# Epoch 13/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7769 - accuracy: 0.4875 - val_loss: 0.7238 - val_accuracy: 0.5500
# Epoch 14/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7712 - accuracy: 0.4875 - val_loss: 0.7200 - val_accuracy: 0.5500
# Epoch 15/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7658 - accuracy: 0.4875 - val_loss: 0.7165 - val_accuracy: 0.5500
# Epoch 16/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7612 - accuracy: 0.4875 - val_loss: 0.7129 - val_accuracy: 0.5500
# Epoch 17/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7562 - accuracy: 0.4875 - val_loss: 0.7099 - val_accuracy: 0.5500
# Epoch 18/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7519 - accuracy: 0.4875 - val_loss: 0.7069 - val_accuracy: 0.5500
# Epoch 19/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7477 - accuracy: 0.4875 - val_loss: 0.7041 - val_accuracy: 0.5500
# Epoch 20/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7437 - accuracy: 0.4875 - val_loss: 0.7015 - val_accuracy: 0.5500
# Epoch 21/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7398 - accuracy: 0.4875 - val_loss: 0.6992 - val_accuracy: 0.5500
# Epoch 22/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.7362 - accuracy: 0.4875 - val_loss: 0.6971 - val_accuracy: 0.5500
# Epoch 23/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7332 - accuracy: 0.4875 - val_loss: 0.6949 - val_accuracy: 0.5500
# Epoch 24/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.7298 - accuracy: 0.4875 - val_loss: 0.6931 - val_accuracy: 0.5500
# Epoch
100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6598 - accuracy: 0.6425 - val_loss: 0.6511 - val_accuracy: 0.6900
# Epoch 91/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6587 - accuracy: 0.6525 - val_loss: 0.6499 - val_accuracy: 0.6900
# Epoch 92/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6575 - accuracy: 0.6600 - val_loss: 0.6488 - val_accuracy: 0.7000
# Epoch 93/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6563 - accuracy: 0.6625 - val_loss: 0.6478 - val_accuracy: 0.7100
# Epoch 94/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6551 - accuracy: 0.6675 - val_loss: 0.6467 - val_accuracy: 0.7300
# Epoch 95/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6538 - accuracy: 0.6675 - val_loss: 0.6455 - val_accuracy: 0.7300
# Epoch 96/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6526 - accuracy: 0.6700 - val_loss: 0.6442 - val_accuracy: 0.7300
# Epoch 97/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6513 - accuracy: 0.6850 - val_loss: 0.6431 - val_accuracy: 0.7400
# Epoch 98/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6499 - accuracy: 0.6875 - val_loss: 0.6417 - val_accuracy: 0.7500
# Epoch 99/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6485 - accuracy: 0.6900 - val_loss: 0.6404 - val_accuracy: 0.7500
# Epoch 100/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6472 - accuracy: 0.7025 - val_loss: 0.6392 - val_accuracy: 0.7500

# %%
model.get_weights()
# Out:
# [array([[ 1.3907776 ,  1.3907776 ],
#         [-0.44632146, -0.44632146]], dtype=float32),
#  array([-0.14566956, -0.14566956], dtype=float32),
#  array([[0.33679777],
#         [0.33679777]], dtype=float32),
#  array([-0.19860871], dtype=float32)]

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x, y.astype('int'), clf=model, legend=2)
# Out:
# 9600/9600 [==============================] - 15s 2ms/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-b14249697c71> in <cell line: 2>()
#       1 from mlxtend.plotting import plot_decision_regions
# ----> 2 plot_decision_regions(x, y.astype('int'), clf=model, legend=2)
#
# /usr/local/lib/python3.9/dist-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, res, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, scatter_highlight_kwargs)
#     242                antialiased=True)
#     243
# --> 244     ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
#     245
#     246     # Scatter training data samples
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_base.py in axis(self, arg, emit, **kwargs)
#    2125             self.set_ylim(ymin, ymax, emit=emit, auto=yauto)
#    2126         if kwargs:
# -> 2127             raise _api.kwarg_error("axis", kwargs)
#    2128         return (*self.get_xlim(), *self.get_ylim())
#    2129
#
# TypeError: axis() got an unexpected keyword argument 'y_min'

# %%
# Kernel initialization he normal
model= Sequential()
model.add(Dense(2, activation='relu', input_dim=2, kernel_initializer='he_normal'))
model.add(Dense(2, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(2, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 2)                 6
#
#  dense_3 (Dense)             (None, 2)                 6
#
#  dense_4 (Dense)             (None, 2)                 6
#
#  dense_5 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.get_weights()
# Out:
# [array([[ 1.4555504 , -0.09284732],
#         [ 0.9323591 ,  0.6503491 ]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[-0.25478005, -0.537521  ],
#         [ 0.04421583,  1.3408465 ]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[-0.01742745, -0.903788  ],
#         [ 1.1547415 ,  0.5869832 ]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[-0.3097254],
#         [ 1.0778784]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x, y.astype('int'), clf=model, legend=2)
# Out:
# 9600/9600 [==============================] - 13s 1ms/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-b14249697c71> in <cell line: 2>()
#       1 from mlxtend.plotting import plot_decision_regions
# ----> 2 plot_decision_regions(x, y.astype('int'), clf=model, legend=2)
#
# /usr/local/lib/python3.9/dist-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, res, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, scatter_highlight_kwargs)
#     242                antialiased=True)
#     243
# --> 244     ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
#     245
#     246     # Scatter training data samples
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_base.py in axis(self, arg, emit, **kwargs)
#    2125             self.set_ylim(ymin, ymax, emit=emit, auto=yauto)
#    2126         if kwargs:
# -> 2127             raise _api.kwarg_error("axis", kwargs)
#    2128         return (*self.get_xlim(), *self.get_ylim())
#    2129
#
# TypeError: axis() got an unexpected keyword argument 'y_min'
